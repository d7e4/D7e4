# %% [markdown]
# <a href="https://colab.research.google.com/github/d7e4/D7e4/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
for b in range(0,100):
  print (b+1, "^", "2", "=", (b+1)*(b+1))
# Out:
# 1 ^ 2 = 1
# 2 ^ 2 = 4
# 3 ^ 2 = 9
# 4 ^ 2 = 16
# 5 ^ 2 = 25
# 6 ^ 2 = 36
# 7 ^ 2 = 49
# 8 ^ 2 = 64
# 9 ^ 2 = 81
# 10 ^ 2 = 100
# 11 ^ 2 = 121
# 12 ^ 2 = 144
# 13 ^ 2 = 169
# 14 ^ 2 = 196
# 15 ^ 2 = 225
# 16 ^ 2 = 256
# 17 ^ 2 = 289
# 18 ^ 2 = 324
# 19 ^ 2 = 361
# 20 ^ 2 = 400
# 21 ^ 2 = 441
# 22 ^ 2 = 484
# 23 ^ 2 = 529
# 24 ^ 2 = 576
# 25 ^ 2 = 625
# 26 ^ 2 = 676
# 27 ^ 2 = 729
# 28 ^ 2 = 784
# 29 ^ 2 = 841
# 30 ^ 2 = 900
# 31 ^ 2 = 961
# 32 ^ 2 = 1024
# 33 ^ 2 = 1089
# 34 ^ 2 = 1156
# 35 ^ 2 = 1225
# 36 ^ 2 = 1296
# 37 ^ 2 = 1369
# 38 ^ 2 = 1444
# 39 ^ 2 = 1521
# 40 ^ 2 = 1600
# 41 ^ 2 = 1681
# 42 ^ 2 = 1764
# 43 ^ 2 = 1849
# 44 ^ 2 = 1936
# 45 ^ 2 = 2025
# 46 ^ 2 = 2116
# 47 ^ 2 = 2209
# 48 ^ 2 = 2304
# 49 ^ 2 = 2401
# 50 ^ 2 = 2500
# 51 ^ 2 = 2601
# 52 ^ 2 = 2704
# 53 ^ 2 = 2809
# 54 ^ 2 = 2916
# 55 ^ 2 = 3025
# 56 ^ 2 = 3136
# 57 ^ 2 = 3249
# 58 ^ 2 = 3364
# 59 ^ 2 = 3481
# 60 ^ 2 = 3600
# 61 ^ 2 = 3721
# 62 ^ 2 = 3844
# 63 ^ 2 = 3969
# 64 ^ 2 = 4096
# 65 ^ 2 = 4225
# ...

# %%
for i in range(1, 10):
   for j in range(1, 10):
       print(i, '*', j, '=', i * j, end='\t\t')
   print()
# Out:
# 1 * 1 = 1		1 * 2 = 2		1 * 3 = 3		1 * 4 = 4		1 * 5 = 5		1 * 6 = 6		1 * 7 = 7		1 * 8 = 8		1 * 9 = 9
# 2 * 1 = 2		2 * 2 = 4		2 * 3 = 6		2 * 4 = 8		2 * 5 = 10		2 * 6 = 12		2 * 7 = 14		2 * 8 = 16		2 * 9 = 18
# 3 * 1 = 3		3 * 2 = 6		3 * 3 = 9		3 * 4 = 12		3 * 5 = 15		3 * 6 = 18		3 * 7 = 21		3 * 8 = 24		3 * 9 = 27
# 4 * 1 = 4		4 * 2 = 8		4 * 3 = 12		4 * 4 = 16		4 * 5 = 20		4 * 6 = 24		4 * 7 = 28		4 * 8 = 32		4 * 9 = 36
# 5 * 1 = 5		5 * 2 = 10		5 * 3 = 15		5 * 4 = 20		5 * 5 = 25		5 * 6 = 30		5 * 7 = 35		5 * 8 = 40		5 * 9 = 45
# 6 * 1 = 6		6 * 2 = 12		6 * 3 = 18		6 * 4 = 24		6 * 5 = 30		6 * 6 = 36		6 * 7 = 42		6 * 8 = 48		6 * 9 = 54
# 7 * 1 = 7		7 * 2 = 14		7 * 3 = 21		7 * 4 = 28		7 * 5 = 35		7 * 6 = 42		7 * 7 = 49		7 * 8 = 56		7 * 9 = 63
# 8 * 1 = 8		8 * 2 = 16		8 * 3 = 24		8 * 4 = 32		8 * 5 = 40		8 * 6 = 48		8 * 7 = 56		8 * 8 = 64		8 * 9 = 72
# 9 * 1 = 9		9 * 2 = 18		9 * 3 = 27		9 * 4 = 36		9 * 5 = 45		9 * 6 = 54		9 * 7 = 63		9 * 8 = 72		9 * 9 = 81

# %%
for b in range(1,10):
  for c in range(1,10):
    print (b,"*",(c+1), "=",((c+1)*b))
# Out:
# 1 * 2 = 2
# 1 * 3 = 3
# 1 * 4 = 4
# 1 * 5 = 5
# 1 * 6 = 6
# 1 * 7 = 7
# 1 * 8 = 8
# 1 * 9 = 9
# 1 * 10 = 10
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18
# 2 * 10 = 20
# 3 * 2 = 6
# 3 * 3 = 9
# 3 * 4 = 12
# 3 * 5 = 15
# 3 * 6 = 18
# 3 * 7 = 21
# 3 * 8 = 24
# 3 * 9 = 27
# 3 * 10 = 30
# 4 * 2 = 8
# 4 * 3 = 12
# 4 * 4 = 16
# 4 * 5 = 20
# 4 * 6 = 24
# 4 * 7 = 28
# 4 * 8 = 32
# 4 * 9 = 36
# 4 * 10 = 40
# 5 * 2 = 10
# 5 * 3 = 15
# 5 * 4 = 20
# 5 * 5 = 25
# 5 * 6 = 30
# 5 * 7 = 35
# 5 * 8 = 40
# 5 * 9 = 45
# 5 * 10 = 50
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60
# 7 * 2 = 14
# 7 * 3 = 21
# 7 * 4 = 28
# 7 * 5 = 35
# 7 * 6 = 42
# 7 * 7 = 49
# 7 * 8 = 56
# 7 * 9 = 63
# 7 * 10 = 70
# 8 * 2 = 16
# 8 * 3 = 24
# 8 * 4 = 32
# 8 * 5 = 40
# 8 * 6 = 48
# 8 * 7 = 56
# 8 * 8 = 64
# 8 * 9 = 72
# 8 * 10 = 80
# 9 * 2 = 18
# 9 * 3 = 27
# 9 * 4 = 36
# 9 * 5 = 45
# 9 * 6 = 54
# ...

# %%
D=[]
for i in range(1, int(10) + 1):
  for j in range(1, 11):
    print(i, '+', j, '=', i + j)
# Out:
# 1 + 1 = 2
# 1 + 2 = 3
# 1 + 3 = 4
# 1 + 4 = 5
# 1 + 5 = 6
# 1 + 6 = 7
# 1 + 7 = 8
# 1 + 8 = 9
# 1 + 9 = 10
# 1 + 10 = 11
# 2 + 1 = 3
# 2 + 2 = 4
# 2 + 3 = 5
# 2 + 4 = 6
# 2 + 5 = 7
# 2 + 6 = 8
# 2 + 7 = 9
# 2 + 8 = 10
# 2 + 9 = 11
# 2 + 10 = 12
# 3 + 1 = 4
# 3 + 2 = 5
# 3 + 3 = 6
# 3 + 4 = 7
# 3 + 5 = 8
# 3 + 6 = 9
# 3 + 7 = 10
# 3 + 8 = 11
# 3 + 9 = 12
# 3 + 10 = 13
# 4 + 1 = 5
# 4 + 2 = 6
# 4 + 3 = 7
# 4 + 4 = 8
# 4 + 5 = 9
# 4 + 6 = 10
# 4 + 7 = 11
# 4 + 8 = 12
# 4 + 9 = 13
# 4 + 10 = 14
# 5 + 1 = 6
# 5 + 2 = 7
# 5 + 3 = 8
# 5 + 4 = 9
# 5 + 5 = 10
# 5 + 6 = 11
# 5 + 7 = 12
# 5 + 8 = 13
# 5 + 9 = 14
# 5 + 10 = 15
# 6 + 1 = 7
# 6 + 2 = 8
# 6 + 3 = 9
# 6 + 4 = 10
# 6 + 5 = 11
# 6 + 6 = 12
# 6 + 7 = 13
# 6 + 8 = 14
# 6 + 9 = 15
# 6 + 10 = 16
# 7 + 1 = 8
# 7 + 2 = 9
# 7 + 3 = 10
# 7 + 4 = 11
# 7 + 5 = 12
# 7 + 6 = 13
# 7 + 7 = 14
# 7 + 8 = 15
# 7 + 9 = 16
# 7 + 10 = 17
# 8 + 1 = 9
# 8 + 2 = 10
# 8 + 3 = 11
# 8 + 4 = 12
# 8 + 5 = 13
# 8 + 6 = 14
# 8 + 7 = 15
# 8 + 8 = 16
# 8 + 9 = 17
# ...

# %%
import pandas as pd

# %%
a=[]
b=[]
c=[]
for i in range(1, 4):
  for j in range(1, 4):
   a.append(i)
   b.append (j)
   c.append(i + j)
data=pd.DataFrame(data=[c], index=a, columns=b)
data
# Out:
#    1  2  3  1  2  3  1  2  3
# 1  2  3  4  3  4  5  4  5  6
# 1  2  3  4  3  4  5  4  5  6
# 1  2  3  4  3  4  5  4  5  6
# 2  2  3  4  3  4  5  4  5  6
# 2  2  3  4  3  4  5  4  5  6
# 2  2  3  4  3  4  5  4  5  6
# 3  2  3  4  3  4  5  4  5  6
# 3  2  3  4  3  4  5  4  5  6
# 3  2  3  4  3  4  5  4  5  6

# %%
data=pd.read_csv('http://intersyn.net/Churn.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %%
data=pd.read_csv('shootings_USA.csv')

# %%
data
# Out:
#         id                name        date   manner_of_death       armed  \
# 0        3          Tim Elliot  2015-01-02              shot         gun
# 1        4    Lewis Lee Lembke  2015-01-02              shot         gun
# 2        5  John Paul Quintero  2015-01-03  shot and Tasered     unarmed
# 3        8     Matthew Hoffman  2015-01-04              shot  toy weapon
# 4        9   Michael Rodriguez  2015-01-04              shot    nail gun
# ...    ...                 ...         ...               ...         ...
# 4840  5916     Rayshard Brooks  2020-06-12              shot       Taser
# 4841  5925      Caine Van Pelt  2020-06-12              shot         gun
# 4842  5918        Hannah Fizer  2020-06-13              shot     unarmed
# 4843  5921      William Slyter  2020-06-13              shot         gun
# 4844  5924      Nicholas Hirsh  2020-06-15              shot         gun
#
#        age gender      race           city state  signs_of_mental_illness  \
# ...

# %%
erer=pd.read_excel('Russia.xlsx')

# %%
erer
# Out:
#                                     Наименование  \
# 0                                 Алтайский край
# 1                               Амурская область
# 2   Архангельская область без автономного округа
# 3                           Астраханская область
# 4                           Белгородская область
# ..                                           ...
# 80                          Чеченская Республика
# 81                Чувашская Республика — Чувашия
# 82                    Чукотский автономный округ
# 83               Ямало-Ненецкий автономный округ
# 84                           Ярославская область
#
#     Средняя продолжительность жизни ЖЕНЩИН  \
# 0                                    75.16
# 1                                    72.79
# 2                                    77.01
# 3                                    76.35
# 4                                    77.12
# ..                                     ...
# 80                                   74.65
# ...

# %%
trtr=pd.read_json('EmployeeData.json')

# %%
trtr
# Out:
#       id                 name                               email  \
# 0   4051                manoj                     manoj@gmail.com
# 1   4050               pankaj                        p1@gmail.com
# 2   3050           Neeraj1993   neeraj.singh@adequateinfosoft.com
# 3   3049               Sophia                    sophia@gmail.com
# 4   3048          Raju Prasad                 raju.nsit@gmail.com
# 5   3047    Ankiish Thapliyal       thapliyalankiish958@gmail.com
# 6   3046      Aryan Thapliyal            ashithewarrior@gmail.com
# 7   3045               shivam                    shivam@gmail.com
# 8   3044       Navya Upadhyay            navya.adequate@gmail.com
# 9   3043           Ritu singh         ritusinghadequate@gmail.com
# 10  3042                 faiz              faizadequate@gmail.com
# 11  3041        Martin Wilson          ravencomputer667@gmail.com
# 12  3040         Shweta Singh          amelia.claire.hi@gmail.com
# ...

# %%
trtr.to_excel("ttt.xlsx")

# %%
# !pip install yfinance

# %%
import yfinance as yf

# %%
yf.download(tickers="AAPL", period="2d", interval="1h", group_by="column")
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-08-24 09:30:00-04:00  180.520004  181.104004  178.389999  178.401993
# 2023-08-24 10:30:00-04:00  178.409897  178.456207  177.649994  178.125000
# 2023-08-24 11:30:00-04:00  178.119995  178.300003  177.500000  178.059906
# 2023-08-24 12:30:00-04:00  178.050003  178.309998  177.680603  177.740005
# 2023-08-24 13:30:00-04:00  177.729996  177.929993  177.429993  177.524002
# 2023-08-24 14:30:00-04:00  177.520004  177.639999  176.800003  176.820007
# 2023-08-24 15:30:00-04:00  176.820007  176.889999  176.009995  176.330002
# 2023-08-25 09:30:00-04:00  177.380005  178.630005  176.820007  177.009995
# 2023-08-25 10:30:00-04:00  177.014999  177.410004  175.869995  177.360001
# 2023-08-25 11:30:00-04:00  177.360001  177.770004  176.550003  177.750000
# 2023-08-25 12:30:00-04:00  177.750000  177.839996  177.089996  177.399902
# ...

# %%
sega=pd.read_csv("SegaGames.csv")

# %%
sega
# Out:
#       meta_score                           title platform          date  \
# 0            NaN                Persona 3 Reload     XONE   Feb 2, 2024
# 1            NaN               Persona 5 Tactica       PC  Nov 17, 2023
# 2            NaN               Persona 5 Tactica     XONE  Nov 17, 2023
# 3            NaN               Persona 5 Tactica      PS4  Nov 17, 2023
# 4            NaN               Persona 5 Tactica   Switch  Nov 17, 2023
# ...          ...                             ...      ...           ...
# 1476         NaN   Samba de Amigo: Party Central       PC       Q4 2023
# 1477         NaN  Like a Dragon: Infinite Wealth       PC      TBA 2024
# 1478         NaN  Like a Dragon: Infinite Wealth      PS4      TBA 2024
# 1479         NaN  Like a Dragon: Infinite Wealth     XONE      TBA 2024
# 1480         NaN     Samba de Amigo: Party-To-Go      iOS   August 2023
#
#       user_score                                               link  \
# ...

# %%
sega.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1481 entries, 0 to 1480
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   meta_score   788 non-null    float64
#  1   title        1481 non-null   object
#  2   platform     1481 non-null   object
#  3   date         1481 non-null   object
#  4   user_score   929 non-null    float64
#  5   link         1481 non-null   object
#  6   esrb_rating  1120 non-null   object
#  7   developers   1471 non-null   object
#  8   genres       1479 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 104.3+ KB

# %%
sega.describe()
# Out:
#        meta_score  user_score
# count  788.000000  929.000000
# mean    72.230964    7.324112
# std     12.456173    1.202780
# min     26.000000    1.700000
# 25%     65.000000    6.700000
# 50%     74.000000    7.600000
# 75%     82.000000    8.200000
# max     97.000000    9.600000

# %%
import pandas as pd

# %%
df=pd.DataFrame({'x':[1,2,3], 'y':[2,4,1]})

# %%
df
# Out:
#    x  y
# 0  1  2
# 1  2  4
# 2  3  1

# %%
df.drop(1,axis=0, inplace=True)

# %%
df
# Out:
#    x  y
# 0  1  2
# 2  3  1

# %%
del df['x']

# %%
df
# Out:
#    y
# 0  2
# 2  1

# %%
df.reset_index(drop=True)
# Out:
#    y
# 0  2
# 1  1

# %%
df1=pd.DataFrame({'x':[1,3,3], 'y':[2,5,1]})

# %%
df2=pd.DataFrame({'x':[1,2,3], 'y':[2,4,1]})

# %%
print(df1<=df2)
# Out:
#        x      y
# 0   True   True
# 1  False  False
# 2   True   True

# %%
df1[(df1>1)&(df1==2)]
# Out:
#     x    y
# 0 NaN  2.0
# 1 NaN  NaN
# 2 NaN  NaN

# %%
df1[(df1>1)|(df1==2)]
# Out:
#      x    y
# 0  NaN  2.0
# 1  3.0  5.0
# 2  3.0  NaN

# %%
data={'Имя':['Аннаа', 'Ben', None, 'Jon'], 'Age':[25,30,28,None]}

# %%
df=pd.DataFrame(data)

# %%
df
# Out:
#      Имя   Age
# 0  Аннаа  25.0
# 1    Ben  30.0
# 2   None  28.0
# 3    Jon   NaN

# %%
df.isna().loc[df['Имя']==True]
# Out:
# Empty DataFrame
# Columns: [Имя, Age]
# Index: []

# %%
1+1
# Out:
# 2
